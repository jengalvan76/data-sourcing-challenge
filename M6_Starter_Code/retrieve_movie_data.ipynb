# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
query_url = f"{url}&api-key={nyt_api_key}&fq={filter_query}&begin_date={begin_date}&end_date={end_date}&sort={sort}&fl={field_list}"

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page in range(0,20):

    # create query with a page number
    query_url = f"{query_url}&page={page+1}"
    try: 
        
        # Make a "GET" request and retrieve the JSON
        response_json = requests.get(query_url).json()

        # API results show 10 articles at a time
        for review in response_json["response"]["docs"]:
            reviews_list.append(review)

        # Print the page that was just retrieved
        print(f"Checked page {page}")
        # Print(reviews_list[0])
    except: 
        print(f"Page number {page} had no results")


    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
# Out:
# Checked page 0
# Checked page 1
# Checked page 2
# Checked page 3
# Checked page 4
# Checked page 5
# Checked page 6
# Checked page 7
# Checked page 8
# Checked page 9
# Checked page 10
# Checked page 11
# Checked page 12
# Checked page 13
# Checked page 14
# Checked page 15
# Checked page 16
# Checked page 17
# Checked page 18
# Checked page 19

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
first_five_reviews = reviews_list[0:5]
print(json.dumps(first_five_reviews, indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/01/31/movies/pamela-a-love-story-review.html",
#         "snippet": "This documentary from Ryan White rewinds, to powerful effect, on Pamela Anderson\u2019s life and fame.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Pamela, a Love Story\u2019 Review: A Frank Look Back",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Pamela, a Love Story",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Anderson, Pamela (1967- )",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "White, Ryan (Filmmaker)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Pamela, a Love Story (Movie)",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-01-31T12:00:05+0000",
#         "byline": {
#             "original": "By Glenn Kenny",
#             "person": [
#                 {
#                     "firstname": "Glenn",
#                     "middlename": null,
#                     "lastname": "Kenny",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/01/19/movies/in-from-the-side-review.html",
#         "snippet": "In Matt Carter\u2019s gay rugby film, sports and romance smash together like two players from opposing teams.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018In From the Side\u2019 Review: Love and Rugby Play a Losing Game",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "In From the Side",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "In From the Side (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Carter, Matt (Filmmaker)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-01-19T17:50:16+0000",
#         "byline": {
#             "original": "By Kyle Turner",
#             "person": [
#                 {
#                     "firstname": "Kyle",
#                     "middlename": null,
#                     "lastname": "Turner",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 281
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/01/19/movies/after-love-review.html",
#         "snippet": "In this intelligent melodrama by the director Aleem Khan, a British woman discovers her husband has been leading a double life.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018After Love\u2019 Review: The Other Woman",
#             "kicker": "Critic\u2019s Pick",
#             "content_kicker": null,
#             "print_headline": "After Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "After Love (2020) (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Khan, Aleem",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Scanlan, Joanna (1961- )",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-01-19T12:00:06+0000",
#         "byline": {
#             "original": "By Beatrice Loayza",
#             "person": [
#                 {
#                     "firstname": "Beatrice",
#                     "middlename": null,
#                     "lastname": "Loayza",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 359
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/01/05/movies/alcarras-review.html",
#         "snippet": "In this naturalistic drama from Spain, a family confronts the impending loss of its generations-old farm.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Alcarr\u00e0s\u2019 Review: Labor of Love",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Alcarr\u00e0s",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Simon, Carla",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Alcarras (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-01-05T12:00:03+0000",
#         "byline": {
#             "original": "By Devika Girish",
#             "person": [
#                 {
#                     "firstname": "Devika",
#                     "middlename": null,
#                     "lastname": "Girish",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 306
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/12/15/movies/nelly-and-nadine-review.html",
#         "snippet": "A family archive provides intimate records of a love affair that began between two women imprisoned in the Ravensbr\u00fcck concentration camp.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Nelly & Nadine\u2019 Review: An Unlikely Love, an Unlikely Record",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Nelly &amp; Nadine",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Gertten, Magnus",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Nelly & Nadine (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Content Type: Personal Profile",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Holocaust and the Nazi Era",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "World War II (1939-45)",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Women and Girls",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Homosexuality and Bisexuality",
#                 "rank": 8,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-12-15T12:00:04+0000",
#         "byline": {
#             "original": "By Teo Bugbee",
#             "person": [
#                 {
#                     "firstname": "Teo",
#                     "middlename": null,
#                     "lastname": "Bugbee",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 308
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
reviews_list_df = pd.json_normalize(reviews_list)
reviews_list_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/01/31/movies/pame...
# 1    https://www.nytimes.com/2023/01/19/movies/in-f...
# 2    https://www.nytimes.com/2023/01/19/movies/afte...
# 3    https://www.nytimes.com/2023/01/05/movies/alca...
# 4    https://www.nytimes.com/2022/12/15/movies/nell...
# ..                                                 ...
# 195  https://www.nytimes.com/2022/12/01/movies/lady...
# 196  https://www.nytimes.com/2022/11/23/movies/soun...
# 197  https://www.nytimes.com/2022/11/17/movies/the-...
# 198  https://www.nytimes.com/2022/11/17/movies/bone...
# 199  https://www.nytimes.com/2022/10/20/movies/my-p...
#
#                                                snippet              source  \
# 0    This documentary from Ryan White rewinds, to p...  The New York Times
# 1    In Matt Carter’s gay rugby film, sports and ro...  The New York Times
# 2    In this intelligent melodrama by the director ...  The New York Times
# 3    In this naturalistic drama from Spain, a famil...  The New York Times
# 4    A family archive provides intimate records of ...  The New York Times
# ..                                                 ...                 ...
# 195  The new Netflix adaptation of D.H. Lawrence’s ...  The New York Times
# 196  A young singer gets more than she bargained fo...  The New York Times
# 197  Elegance Bratton’s autobiographical first feat...  The New York Times
# 198  Luca Guadagnino’s latest stars Timothée Chalam...  The New York Times
# 199  A schoolteacher, her police officer husband an...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Documentary Fil...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Documentary Fil...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 197  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                      pub_date  word_count  \
# 0    2023-01-31T12:00:05+0000         295
# 1    2023-01-19T17:50:16+0000         281
# 2    2023-01-19T12:00:06+0000         359
# 3    2023-01-05T12:00:03+0000         306
# 4    2022-12-15T12:00:04+0000         308
# ..                        ...         ...
# 195  2022-12-01T16:40:55+0000         768
# 196  2022-11-23T15:00:09+0000         277
# 197  2022-11-17T12:00:07+0000         836
# 198  2022-11-17T12:00:06+0000         710
# 199  2022-10-20T16:52:51+0000         303
#
#                                          headline.main headline.kicker  \
# 0     ‘Pamela, a Love Story’ Review: A Frank Look Back            None
# 1    ‘In From the Side’ Review: Love and Rugby Play...            None
# 2                 ‘After Love’ Review: The Other Woman   Critic’s Pick
# 3                     ‘Alcarràs’ Review: Labor of Love            None
# 4    ‘Nelly & Nadine’ Review: An Unlikely Love, an ...            None
# ..                                                 ...             ...
# 195  ‘Lady Chatterley’s Lover’ Review: When Connie ...            None
# 196  ‘The Sound of Christmas’ Review: A Gospel Sing...            None
# 197   ‘The Inspection’ Review: Boot Camp, a Love Story   critic’s pick
# 198       ‘Bones and All’ Review: You Eat What You Are            None
# 199  ‘My Policeman’ Review: Two Love Affairs, Equal...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                                 Pamela, a Love Story          None
# 1                                     In From the Side          None
# 2                                           After Love          None
# 3                                             Alcarràs          None
# 4                                   Nelly &amp; Nadine          None
# ..                                                 ...           ...
# 195                  A Love Whose Name Is Often Spoken          None
# 196                            The Sound  Of Christmas          None
# 197                  A Few Good Men, Some With Secrets          None
# 198  It’s Eat, Prey, Love on a Journey of Self-Disc...          None
# 199                                       My Policeman          None
#
#     headline.seo headline.sub        byline.original  \
# 0           None         None         By Glenn Kenny
# 1           None         None         By Kyle Turner
# 2           None         None     By Beatrice Loayza
# 3           None         None       By Devika Girish
# 4           None         None          By Teo Bugbee
# ..           ...          ...                    ...
# 195         None         None          By A.O. Scott
# 196         None         None  By Concepción de León
# 197         None         None          By A.O. Scott
# 198         None         None          By A.O. Scott
# 199         None         None          By Teo Bugbee
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 1    [{'firstname': 'Kyle', 'middlename': None, 'la...                None
# 2    [{'firstname': 'Beatrice', 'middlename': None,...                None
# 3    [{'firstname': 'Devika', 'middlename': None, '...                None
# 4    [{'firstname': 'Teo', 'middlename': None, 'las...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 196  [{'firstname': 'Concepción', 'middlename': Non...                None
# 197  [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 198  [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 199  [{'firstname': 'Teo', 'middlename': None, 'las...                None
#
# [200 rows x 16 columns]

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
reviews_list_df["title"] = reviews_list_df["headline.main"].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])
reviews_list_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/01/31/movies/pame...
# 1    https://www.nytimes.com/2023/01/19/movies/in-f...
# 2    https://www.nytimes.com/2023/01/19/movies/afte...
# 3    https://www.nytimes.com/2023/01/05/movies/alca...
# 4    https://www.nytimes.com/2022/12/15/movies/nell...
# ..                                                 ...
# 195  https://www.nytimes.com/2022/12/01/movies/lady...
# 196  https://www.nytimes.com/2022/11/23/movies/soun...
# 197  https://www.nytimes.com/2022/11/17/movies/the-...
# 198  https://www.nytimes.com/2022/11/17/movies/bone...
# 199  https://www.nytimes.com/2022/10/20/movies/my-p...
#
#                                                snippet              source  \
# 0    This documentary from Ryan White rewinds, to p...  The New York Times
# 1    In Matt Carter’s gay rugby film, sports and ro...  The New York Times
# 2    In this intelligent melodrama by the director ...  The New York Times
# 3    In this naturalistic drama from Spain, a famil...  The New York Times
# 4    A family archive provides intimate records of ...  The New York Times
# ..                                                 ...                 ...
# 195  The new Netflix adaptation of D.H. Lawrence’s ...  The New York Times
# 196  A young singer gets more than she bargained fo...  The New York Times
# 197  Elegance Bratton’s autobiographical first feat...  The New York Times
# 198  Luca Guadagnino’s latest stars Timothée Chalam...  The New York Times
# 199  A schoolteacher, her police officer husband an...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Documentary Fil...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Documentary Fil...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 197  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                      pub_date  word_count  \
# 0    2023-01-31T12:00:05+0000         295
# 1    2023-01-19T17:50:16+0000         281
# 2    2023-01-19T12:00:06+0000         359
# 3    2023-01-05T12:00:03+0000         306
# 4    2022-12-15T12:00:04+0000         308
# ..                        ...         ...
# 195  2022-12-01T16:40:55+0000         768
# 196  2022-11-23T15:00:09+0000         277
# 197  2022-11-17T12:00:07+0000         836
# 198  2022-11-17T12:00:06+0000         710
# 199  2022-10-20T16:52:51+0000         303
#
#                                          headline.main headline.kicker  \
# 0     ‘Pamela, a Love Story’ Review: A Frank Look Back            None
# 1    ‘In From the Side’ Review: Love and Rugby Play...            None
# 2                 ‘After Love’ Review: The Other Woman   Critic’s Pick
# 3                     ‘Alcarràs’ Review: Labor of Love            None
# 4    ‘Nelly & Nadine’ Review: An Unlikely Love, an ...            None
# ..                                                 ...             ...
# 195  ‘Lady Chatterley’s Lover’ Review: When Connie ...            None
# 196  ‘The Sound of Christmas’ Review: A Gospel Sing...            None
# 197   ‘The Inspection’ Review: Boot Camp, a Love Story   critic’s pick
# 198       ‘Bones and All’ Review: You Eat What You Are            None
# 199  ‘My Policeman’ Review: Two Love Affairs, Equal...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                                 Pamela, a Love Story          None
# 1                                     In From the Side          None
# 2                                           After Love          None
# 3                                             Alcarràs          None
# 4                                   Nelly &amp; Nadine          None
# ..                                                 ...           ...
# 195                  A Love Whose Name Is Often Spoken          None
# 196                            The Sound  Of Christmas          None
# 197                  A Few Good Men, Some With Secrets          None
# 198  It’s Eat, Prey, Love on a Journey of Self-Disc...          None
# 199                                       My Policeman          None
#
#     headline.seo headline.sub        byline.original  \
# 0           None         None         By Glenn Kenny
# 1           None         None         By Kyle Turner
# 2           None         None     By Beatrice Loayza
# 3           None         None       By Devika Girish
# 4           None         None          By Teo Bugbee
# ..           ...          ...                    ...
# 195         None         None          By A.O. Scott
# 196         None         None  By Concepción de León
# 197         None         None          By A.O. Scott
# 198         None         None          By A.O. Scott
# 199         None         None          By Teo Bugbee
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 1    [{'firstname': 'Kyle', 'middlename': None, 'la...                None
# 2    [{'firstname': 'Beatrice', 'middlename': None,...                None
# 3    [{'firstname': 'Devika', 'middlename': None, '...                None
# 4    [{'firstname': 'Teo', 'middlename': None, 'las...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 196  [{'firstname': 'Concepción', 'middlename': Non...                None
# 197  [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 198  [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 199  [{'firstname': 'Teo', 'middlename': None, 'las...                None
#
#                        title
# 0       Pamela, a Love Story
# 1           In From the Side
# 2                 After Love
# 3                   Alcarràs
# 4             Nelly & Nadine
# ..                       ...
# 195  Lady Chatterley’s Lover
# 196   The Sound of Christmas
# 197           The Inspection
# 198            Bones and All
# 199             My Policeman
#
# [200 rows x 17 columns]

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
reviews_list_df["keywords"] = reviews_list_df["keywords"].apply(extract_keywords)
reviews_list_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/01/31/movies/pame...
# 1    https://www.nytimes.com/2023/01/19/movies/in-f...
# 2    https://www.nytimes.com/2023/01/19/movies/afte...
# 3    https://www.nytimes.com/2023/01/05/movies/alca...
# 4    https://www.nytimes.com/2022/12/15/movies/nell...
# ..                                                 ...
# 195  https://www.nytimes.com/2022/12/01/movies/lady...
# 196  https://www.nytimes.com/2022/11/23/movies/soun...
# 197  https://www.nytimes.com/2022/11/17/movies/the-...
# 198  https://www.nytimes.com/2022/11/17/movies/bone...
# 199  https://www.nytimes.com/2022/10/20/movies/my-p...
#
#                                                snippet              source  \
# 0    This documentary from Ryan White rewinds, to p...  The New York Times
# 1    In Matt Carter’s gay rugby film, sports and ro...  The New York Times
# 2    In this intelligent melodrama by the director ...  The New York Times
# 3    In this naturalistic drama from Spain, a famil...  The New York Times
# 4    A family archive provides intimate records of ...  The New York Times
# ..                                                 ...                 ...
# 195  The new Netflix adaptation of D.H. Lawrence’s ...  The New York Times
# 196  A young singer gets more than she bargained fo...  The New York Times
# 197  Elegance Bratton’s autobiographical first feat...  The New York Times
# 198  Luca Guadagnino’s latest stars Timothée Chalam...  The New York Times
# 199  A schoolteacher, her police officer husband an...  The New York Times
#
#                                               keywords  \
# 0    subject: Documentary Films and Programs;person...
# 1    subject: Movies;creative_works: In From the Si...
# 2    subject: Movies;creative_works: After Love (20...
# 3    subject: Movies;persons: Simon, Carla;creative...
# 4    subject: Documentary Films and Programs;person...
# ..                                                 ...
# 195  subject: Movies;creative_works: Lady Chatterle...
# 196  subject: Movies;persons: Ne-Yo;creative_works:...
# 197  subject: Movies;creative_works: The Inspection...
# 198  subject: Movies;creative_works: Bones and All ...
# 199  subject: Movies;creative_works: My Policeman (...
#
#                      pub_date  word_count  \
# 0    2023-01-31T12:00:05+0000         295
# 1    2023-01-19T17:50:16+0000         281
# 2    2023-01-19T12:00:06+0000         359
# 3    2023-01-05T12:00:03+0000         306
# 4    2022-12-15T12:00:04+0000         308
# ..                        ...         ...
# 195  2022-12-01T16:40:55+0000         768
# 196  2022-11-23T15:00:09+0000         277
# 197  2022-11-17T12:00:07+0000         836
# 198  2022-11-17T12:00:06+0000         710
# 199  2022-10-20T16:52:51+0000         303
#
#                                          headline.main headline.kicker  \
# 0     ‘Pamela, a Love Story’ Review: A Frank Look Back            None
# 1    ‘In From the Side’ Review: Love and Rugby Play...            None
# 2                 ‘After Love’ Review: The Other Woman   Critic’s Pick
# 3                     ‘Alcarràs’ Review: Labor of Love            None
# 4    ‘Nelly & Nadine’ Review: An Unlikely Love, an ...            None
# ..                                                 ...             ...
# 195  ‘Lady Chatterley’s Lover’ Review: When Connie ...            None
# 196  ‘The Sound of Christmas’ Review: A Gospel Sing...            None
# 197   ‘The Inspection’ Review: Boot Camp, a Love Story   critic’s pick
# 198       ‘Bones and All’ Review: You Eat What You Are            None
# 199  ‘My Policeman’ Review: Two Love Affairs, Equal...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                                 Pamela, a Love Story          None
# 1                                     In From the Side          None
# 2                                           After Love          None
# 3                                             Alcarràs          None
# 4                                   Nelly &amp; Nadine          None
# ..                                                 ...           ...
# 195                  A Love Whose Name Is Often Spoken          None
# 196                            The Sound  Of Christmas          None
# 197                  A Few Good Men, Some With Secrets          None
# 198  It’s Eat, Prey, Love on a Journey of Self-Disc...          None
# 199                                       My Policeman          None
#
#     headline.seo headline.sub        byline.original  \
# 0           None         None         By Glenn Kenny
# 1           None         None         By Kyle Turner
# 2           None         None     By Beatrice Loayza
# 3           None         None       By Devika Girish
# 4           None         None          By Teo Bugbee
# ..           ...          ...                    ...
# 195         None         None          By A.O. Scott
# 196         None         None  By Concepción de León
# 197         None         None          By A.O. Scott
# 198         None         None          By A.O. Scott
# 199         None         None          By Teo Bugbee
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 1    [{'firstname': 'Kyle', 'middlename': None, 'la...                None
# 2    [{'firstname': 'Beatrice', 'middlename': None,...                None
# 3    [{'firstname': 'Devika', 'middlename': None, '...                None
# 4    [{'firstname': 'Teo', 'middlename': None, 'las...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 196  [{'firstname': 'Concepción', 'middlename': Non...                None
# 197  [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 198  [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 199  [{'firstname': 'Teo', 'middlename': None, 'las...                None
#
#                        title
# 0       Pamela, a Love Story
# 1           In From the Side
# 2                 After Love
# 3                   Alcarràs
# 4             Nelly & Nadine
# ..                       ...
# 195  Lady Chatterley’s Lover
# 196   The Sound of Christmas
# 197           The Inspection
# 198            Bones and All
# 199             My Policeman
#
# [200 rows x 17 columns]

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
titles = reviews_list_df["title"].to_list()
titles
# Out:
# ['Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman']

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 1

# Loop through the titles
    # Check if we need to sleep before making a request
    # Add 1 to the request counter
def getMovieDetails(search_url):

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer " + str(tmdb_api_key)
    }
    response = requests.get(search_url, headers=headers).json()
    return response

for title in titles:
        request_counter = request_counter + 1
        if (request_counter %50 == 0):
                print("The application is sleeping")
                time.sleep(1)
    
    # Perform a "GET" request for The Movie Database
    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.
        # Get movie id
        search_url = url + title + tmdb_key_string 
        response = getMovieDetails(search_url)
        
        try:
                movie_id = response["results"][0]["id"]
                #print(response)
                #print(movie_id)
                search_by_id = "https://api.themoviedb.org/3/movie/" + str(movie_id)
                movie_details = getMovieDetails(search_by_id)
                genres = movie_details["genres"]
                spoken_languages = movie_details["spoken_languages"]
                production_countries = movie_details["production_countries"]
                movie_dict = {}
                movie_dict["title"]= movie_details["title"] 
                movie_dict["original_title"]= movie_details["original_title"] 
                movie_dict["budget"]= movie_details["budget"] 
                movie_dict["original_language"]= movie_details["original_language"] 
                movie_dict["homepage"]= movie_details["homepage"] 
                movie_dict["overview"]= movie_details["overview"] 
                movie_dict["popularity"]= movie_details["popularity"] 
                movie_dict["runtime"]= movie_details["runtime"] 
                movie_dict["revenue"]= movie_details["revenue"] 
                movie_dict["release_date"]= movie_details["release_date"] 
                movie_dict["vote_average"]= movie_details["vote_average"] 
                movie_dict["vote_count"]= movie_details["vote_count"] 
                movie_dict["genres"] = genres 
                movie_dict["spoken_languages"]= spoken_languages 
                movie_dict["production_countries"]= production_countries
                tmdb_movies_list.append(movie_dict)
                print("Found " + title)      
        except IndexError:
                print(f"{title} not found.")

        # Make a request for a the full movie details

        # Execute "GET" request with url
        
        # Extract the genre names into a list
            
        # Extract the spoken_languages' English name into a list

        # Extract the production_countries' name into a list

        # Add the relevant data to a dictionary and

        # append it to the tmdb_movies_list list ({
       
        # Print out the title that was found
# Out:
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# The application is sleeping
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# The application is sleeping
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# The application is sleeping
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# The application is sleeping
# Found Bones and All
# Found My Policeman

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
first_five_movies = tmdb_movies_list[0:5]
print(json.dumps(first_five_movies, indent=4))
# Out:
# [
#     {
#         "title": "Pamela, A Love Story",
#         "original_title": "Pamela, A Love Story",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "https://www.netflix.com/title/81590934",
#         "overview": "In her own words, through personal video and diaries, Pamela Anderson shares the story of her rise to fame, rocky romances and infamous sex tape scandal.",
#         "popularity": 10.614,
#         "runtime": 113,
#         "revenue": 0,
#         "release_date": "2023-01-30",
#         "vote_average": 6.978,
#         "vote_count": 207,
#         "genres": [
#             {
#                 "id": 99,
#                 "name": "Documentary"
#             }
#         ],
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "production_countries": [
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ]
#     },
#     {
#         "title": "In from the Side",
#         "original_title": "In from the Side",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "http://www.infromthesidemovie.com",
#         "overview": "Mark, a new and inexperienced rugby club member, finds himself drawn to Warren, a seasoned first team player. When a series of happenstances at an away fixture lead to a drunken encounter, Mark and Warren unwittingly embark on a romantic affair they struggle to hide from their partners and teammates.",
#         "popularity": 18.786,
#         "runtime": 134,
#         "revenue": 52885,
#         "release_date": "2022-09-16",
#         "vote_average": 6.8,
#         "vote_count": 62,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             }
#         ],
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "production_countries": [
#             {
#                 "iso_3166_1": "GB",
#                 "name": "United Kingdom"
#             }
#         ]
#     },
#     {
#         "title": "After Love",
#         "original_title": "After Love",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "",
#         "overview": "Set in the port town of Dover in the South-East of England, Mary Hussain suddenly finds herself a widow following the unexpected death of her husband. A day after the burial, she discovers he has a secret just twenty-one miles across the English Channel in Calais.",
#         "popularity": 20.945,
#         "runtime": 89,
#         "revenue": 0,
#         "release_date": "2021-06-04",
#         "vote_average": 7.152,
#         "vote_count": 122,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             }
#         ],
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             },
#             {
#                 "english_name": "Arabic",
#                 "iso_639_1": "ar",
#                 "name": "\u0627\u0644\u0639\u0631\u0628\u064a\u0629"
#             },
#             {
#                 "english_name": "French",
#                 "iso_639_1": "fr",
#                 "name": "Fran\u00e7ais"
#             },
#             {
#                 "english_name": "Urdu",
#                 "iso_639_1": "ur",
#                 "name": "\u0627\u0631\u062f\u0648"
#             }
#         ],
#         "production_countries": [
#             {
#                 "iso_3166_1": "GB",
#                 "name": "United Kingdom"
#             }
#         ]
#     },
#     {
#         "title": "Alcarr\u00e0s",
#         "original_title": "Alcarr\u00e0s",
#         "budget": 0,
#         "original_language": "ca",
#         "homepage": "https://www.alcarras-film.com/",
#         "overview": "In a small village in Catalonia, the peach farmers of the Sol\u00e9 family spend every summer together picking fruit from their orchard. But when plans arise to install solar panels and cut down trees, the members of this tight-knit group suddenly face eviction \u2013 and the loss of far more than their home.",
#         "popularity": 14.598,
#         "runtime": 120,
#         "revenue": 0,
#         "release_date": "2022-04-29",
#         "vote_average": 6.867,
#         "vote_count": 180,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             }
#         ],
#         "spoken_languages": [
#             {
#                 "english_name": "Catalan",
#                 "iso_639_1": "ca",
#                 "name": "Catal\u00e0"
#             }
#         ],
#         "production_countries": [
#             {
#                 "iso_3166_1": "ES",
#                 "name": "Spain"
#             }
#         ]
#     },
#     {
#         "title": "Nelly and Monsieur Arnaud",
#         "original_title": "Nelly et Mr. Arnaud",
#         "budget": 0,
#         "original_language": "fr",
#         "homepage": "",
#         "overview": "Nelly leaves her lazy, unemployed husband to work for retired judge Mr Arnaud, forty years her senior, after he offers to clear her bills for her. While she types his memoirs the two develop a close friendship, but Arnaud becomes jealous when Nelly begins dating his good-looking young publisher.",
#         "popularity": 15.338,
#         "runtime": 106,
#         "revenue": 0,
#         "release_date": "1995-08-23",
#         "vote_average": 6.888,
#         "vote_count": 120,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             }
#         ],
#         "spoken_languages": [
#             {
#                 "english_name": "French",
#                 "iso_639_1": "fr",
#                 "name": "Fran\u00e7ais"
#             }
#         ],
#         "production_countries": [
#             {
#                 "iso_3166_1": "DE",
#                 "name": "Germany"
#             },
#             {
#                 "iso_3166_1": "FR",
#                 "name": "France"
#             },
#             {
#                 "iso_3166_1": "IT",
#                 "name": "Italy"
#             }
#         ]
#     }
# ]

# %%
# Convert the results to a DataFrame
tmdb_df = pd.DataFrame(tmdb_movies_list)
tmdb_df
# Out:
#                          title           original_title    budget  \
# 0         Pamela, A Love Story     Pamela, A Love Story         0
# 1             In from the Side         In from the Side         0
# 2                   After Love               After Love         0
# 3                     Alcarràs                 Alcarràs         0
# 4    Nelly and Monsieur Arnaud      Nelly et Mr. Arnaud         0
# ..                         ...                      ...       ...
# 195    Lady Chatterley's Lover  Lady Chatterley's Lover         0
# 196     The Sound of Christmas   The Sound of Christmas         0
# 197             The Inspection           The Inspection         0
# 198              Bones and All            Bones and All  16000000
# 199               My Policeman             My Policeman         0
#
#     original_language                                homepage  \
# 0                  en  https://www.netflix.com/title/81590934
# 1                  en       http://www.infromthesidemovie.com
# 2                  en
# 3                  ca          https://www.alcarras-film.com/
# 4                  fr
# ..                ...                                     ...
# 195                en  https://www.netflix.com/title/81476441
# 196                en
# 197                en   https://a24films.com/films/inspection
# 198                it        https://www.bonesandallfilm.net/
# 199                en    https://www.amazon.com/dp/B09Y8SHDPD
#
#                                               overview  popularity  runtime  \
# 0    In her own words, through personal video and d...      10.614      113
# 1    Mark, a new and inexperienced rugby club membe...      18.786      134
# 2    Set in the port town of Dover in the South-Eas...      20.945       89
# 3    In a small village in Catalonia, the peach far...      14.598      120
# 4    Nelly leaves her lazy, unemployed husband to w...      15.338      106
# ..                                                 ...         ...      ...
# 195  Unhappily married aristocrat Lady Chatterley b...      30.633      126
# 196  A woman facing eviction just before Christmas ...       1.173        0
# 197  Ellis French is a young, gay Black man, reject...      26.393       95
# 198  Abandoned by her father, a young woman embarks...      30.307      131
# 199  In the late 1990s, the arrival of elderly inva...      24.341      113
#
#       revenue release_date  vote_average  vote_count  \
# 0           0   2023-01-30         6.978         207
# 1       52885   2022-09-16         6.800          62
# 2           0   2021-06-04         7.152         122
# 3           0   2022-04-29         6.867         180
# 4           0   1995-08-23         6.888         120
# ..        ...          ...           ...         ...
# 195         0   2022-11-22         6.620         392
# 196         0   2022-11-24         8.000           4
# 197    270613   2022-11-18         6.179          56
# 198  15234907   2022-11-18         7.068        1252
# 199         0   2022-10-20         7.726         639
#
#                                                 genres  \
# 0                  [{'id': 99, 'name': 'Documentary'}]
# 1    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 2                        [{'id': 18, 'name': 'Drama'}]
# 3                        [{'id': 18, 'name': 'Drama'}]
# 4    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# ..                                                 ...
# 195  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 196  [{'id': 10770, 'name': 'TV Movie'}, {'id': 18,...
# 197                      [{'id': 18, 'name': 'Drama'}]
# 198  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 199  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                       spoken_languages  \
# 0    [{'english_name': 'English', 'iso_639_1': 'en'...
# 1    [{'english_name': 'English', 'iso_639_1': 'en'...
# 2    [{'english_name': 'English', 'iso_639_1': 'en'...
# 3    [{'english_name': 'Catalan', 'iso_639_1': 'ca'...
# 4    [{'english_name': 'French', 'iso_639_1': 'fr',...
# ..                                                 ...
# 195  [{'english_name': 'English', 'iso_639_1': 'en'...
# 196  [{'english_name': 'English', 'iso_639_1': 'en'...
# 197  [{'english_name': 'Arabic', 'iso_639_1': 'ar',...
# 198  [{'english_name': 'English', 'iso_639_1': 'en'...
# 199  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                   production_countries
# 0    [{'iso_3166_1': 'US', 'name': 'United States o...
# 1     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# 2     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# 3              [{'iso_3166_1': 'ES', 'name': 'Spain'}]
# 4    [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...
# ..                                                 ...
# 195  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...
# 196  [{'iso_3166_1': 'US', 'name': 'United States o...
# 197  [{'iso_3166_1': 'US', 'name': 'United States o...
# 198  [{'iso_3166_1': 'IT', 'name': 'Italy'}, {'iso_...
# 199  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...
#
# [200 rows x 15 columns]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
combined_title_df = pd.merge(tmdb_df, reviews_list_df, how="inner", on="title")
combined_title_df
# Out:
#              title original_title  budget original_language  \
# 0       After Love     After Love       0                en
# 1       After Love     After Love       0                en
# 2       After Love     After Love       0                en
# 3       After Love     After Love       0                en
# 4       After Love     After Love       0                en
# ...            ...            ...     ...               ...
# 2395  My Policeman   My Policeman       0                en
# 2396  My Policeman   My Policeman       0                en
# 2397  My Policeman   My Policeman       0                en
# 2398  My Policeman   My Policeman       0                en
# 2399  My Policeman   My Policeman       0                en
#
#                                   homepage  \
# 0
# 1
# 2
# 3
# 4
# ...                                    ...
# 2395  https://www.amazon.com/dp/B09Y8SHDPD
# 2396  https://www.amazon.com/dp/B09Y8SHDPD
# 2397  https://www.amazon.com/dp/B09Y8SHDPD
# 2398  https://www.amazon.com/dp/B09Y8SHDPD
# 2399  https://www.amazon.com/dp/B09Y8SHDPD
#
#                                                overview  popularity  runtime  \
# 0     Set in the port town of Dover in the South-Eas...      20.945       89
# 1     Set in the port town of Dover in the South-Eas...      20.945       89
# 2     Set in the port town of Dover in the South-Eas...      20.945       89
# 3     Set in the port town of Dover in the South-Eas...      20.945       89
# 4     Set in the port town of Dover in the South-Eas...      20.945       89
# ...                                                 ...         ...      ...
# 2395  In the late 1990s, the arrival of elderly inva...      24.341      113
# 2396  In the late 1990s, the arrival of elderly inva...      24.341      113
# 2397  In the late 1990s, the arrival of elderly inva...      24.341      113
# 2398  In the late 1990s, the arrival of elderly inva...      24.341      113
# 2399  In the late 1990s, the arrival of elderly inva...      24.341      113
#
#       revenue release_date  ...  \
# 0           0   2021-06-04  ...
# 1           0   2021-06-04  ...
# 2           0   2021-06-04  ...
# 3           0   2021-06-04  ...
# 4           0   2021-06-04  ...
# ...       ...          ...  ...
# 2395        0   2022-10-20  ...
# 2396        0   2022-10-20  ...
# 2397        0   2022-10-20  ...
# 2398        0   2022-10-20  ...
# 2399        0   2022-10-20  ...
#
#                                           headline.main  headline.kicker  \
# 0                  ‘After Love’ Review: The Other Woman    Critic’s Pick
# 1                  ‘After Love’ Review: The Other Woman    Critic’s Pick
# 2                  ‘After Love’ Review: The Other Woman    Critic’s Pick
# 3                  ‘After Love’ Review: The Other Woman    Critic’s Pick
# 4                  ‘After Love’ Review: The Other Woman    Critic’s Pick
# ...                                                 ...              ...
# 2395  ‘My Policeman’ Review: Two Love Affairs, Equal...             None
# 2396  ‘My Policeman’ Review: Two Love Affairs, Equal...             None
# 2397  ‘My Policeman’ Review: Two Love Affairs, Equal...             None
# 2398  ‘My Policeman’ Review: Two Love Affairs, Equal...             None
# 2399  ‘My Policeman’ Review: Two Love Affairs, Equal...             None
#
#      headline.content_kicker headline.print_headline headline.name  \
# 0                       None              After Love          None
# 1                       None              After Love          None
# 2                       None              After Love          None
# 3                       None              After Love          None
# 4                       None              After Love          None
# ...                      ...                     ...           ...
# 2395                    None            My Policeman          None
# 2396                    None            My Policeman          None
# 2397                    None            My Policeman          None
# 2398                    None            My Policeman          None
# 2399                    None            My Policeman          None
#
#      headline.seo headline.sub     byline.original  \
# 0            None         None  By Beatrice Loayza
# 1            None         None  By Beatrice Loayza
# 2            None         None  By Beatrice Loayza
# 3            None         None  By Beatrice Loayza
# 4            None         None  By Beatrice Loayza
# ...           ...          ...                 ...
# 2395         None         None       By Teo Bugbee
# 2396         None         None       By Teo Bugbee
# 2397         None         None       By Teo Bugbee
# 2398         None         None       By Teo Bugbee
# 2399         None         None       By Teo Bugbee
#
#                                           byline.person byline.organization
# 0     [{'firstname': 'Beatrice', 'middlename': None,...                None
# 1     [{'firstname': 'Beatrice', 'middlename': None,...                None
# 2     [{'firstname': 'Beatrice', 'middlename': None,...                None
# 3     [{'firstname': 'Beatrice', 'middlename': None,...                None
# 4     [{'firstname': 'Beatrice', 'middlename': None,...                None
# ...                                                 ...                 ...
# 2395  [{'firstname': 'Teo', 'middlename': None, 'las...                None
# 2396  [{'firstname': 'Teo', 'middlename': None, 'las...                None
# 2397  [{'firstname': 'Teo', 'middlename': None, 'las...                None
# 2398  [{'firstname': 'Teo', 'middlename': None, 'las...                None
# 2399  [{'firstname': 'Teo', 'middlename': None, 'las...                None
#
# [2400 rows x 31 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ["genres", "spoken_languages", "production_countries" ]

# Create a list of characters to remove
characters_to_remove = ["[", "]", "'"]

# Loop through the list of columns to fix

for column in columns_to_fix:
    combined_title_df[column] = combined_title_df[column].astype(str)

    for character in characters_to_remove:
        combined_title_df[column] = combined_title_df[column].str.replace(character, "")

    # Convert the column to type 'str'


    # Loop through characters to remove


# Display the fixed DataFrame
#combined_title_df[columns_to_fix]
combined_title_df
# Out:
#              title original_title  budget original_language  \
# 0       After Love     After Love       0                en
# 1       After Love     After Love       0                en
# 2       After Love     After Love       0                en
# 3       After Love     After Love       0                en
# 4       After Love     After Love       0                en
# ...            ...            ...     ...               ...
# 2395  My Policeman   My Policeman       0                en
# 2396  My Policeman   My Policeman       0                en
# 2397  My Policeman   My Policeman       0                en
# 2398  My Policeman   My Policeman       0                en
# 2399  My Policeman   My Policeman       0                en
#
#                                   homepage  \
# 0
# 1
# 2
# 3
# 4
# ...                                    ...
# 2395  https://www.amazon.com/dp/B09Y8SHDPD
# 2396  https://www.amazon.com/dp/B09Y8SHDPD
# 2397  https://www.amazon.com/dp/B09Y8SHDPD
# 2398  https://www.amazon.com/dp/B09Y8SHDPD
# 2399  https://www.amazon.com/dp/B09Y8SHDPD
#
#                                                overview  popularity  runtime  \
# 0     Set in the port town of Dover in the South-Eas...      20.945       89
# 1     Set in the port town of Dover in the South-Eas...      20.945       89
# 2     Set in the port town of Dover in the South-Eas...      20.945       89
# 3     Set in the port town of Dover in the South-Eas...      20.945       89
# 4     Set in the port town of Dover in the South-Eas...      20.945       89
# ...                                                 ...         ...      ...
# 2395  In the late 1990s, the arrival of elderly inva...      24.341      113
# 2396  In the late 1990s, the arrival of elderly inva...      24.341      113
# 2397  In the late 1990s, the arrival of elderly inva...      24.341      113
# 2398  In the late 1990s, the arrival of elderly inva...      24.341      113
# 2399  In the late 1990s, the arrival of elderly inva...      24.341      113
#
#       revenue release_date  ...  \
# 0           0   2021-06-04  ...
# 1           0   2021-06-04  ...
# 2           0   2021-06-04  ...
# 3           0   2021-06-04  ...
# 4           0   2021-06-04  ...
# ...       ...          ...  ...
# 2395        0   2022-10-20  ...
# 2396        0   2022-10-20  ...
# 2397        0   2022-10-20  ...
# 2398        0   2022-10-20  ...
# 2399        0   2022-10-20  ...
#
#                                           headline.main  headline.kicker  \
# 0                  ‘After Love’ Review: The Other Woman    Critic’s Pick
# 1                  ‘After Love’ Review: The Other Woman    Critic’s Pick
# 2                  ‘After Love’ Review: The Other Woman    Critic’s Pick
# 3                  ‘After Love’ Review: The Other Woman    Critic’s Pick
# 4                  ‘After Love’ Review: The Other Woman    Critic’s Pick
# ...                                                 ...              ...
# 2395  ‘My Policeman’ Review: Two Love Affairs, Equal...             None
# 2396  ‘My Policeman’ Review: Two Love Affairs, Equal...             None
# 2397  ‘My Policeman’ Review: Two Love Affairs, Equal...             None
# 2398  ‘My Policeman’ Review: Two Love Affairs, Equal...             None
# 2399  ‘My Policeman’ Review: Two Love Affairs, Equal...             None
#
#      headline.content_kicker headline.print_headline headline.name  \
# 0                       None              After Love          None
# 1                       None              After Love          None
# 2                       None              After Love          None
# 3                       None              After Love          None
# 4                       None              After Love          None
# ...                      ...                     ...           ...
# 2395                    None            My Policeman          None
# 2396                    None            My Policeman          None
# 2397                    None            My Policeman          None
# 2398                    None            My Policeman          None
# 2399                    None            My Policeman          None
#
#      headline.seo headline.sub     byline.original  \
# 0            None         None  By Beatrice Loayza
# 1            None         None  By Beatrice Loayza
# 2            None         None  By Beatrice Loayza
# 3            None         None  By Beatrice Loayza
# 4            None         None  By Beatrice Loayza
# ...           ...          ...                 ...
# 2395         None         None       By Teo Bugbee
# 2396         None         None       By Teo Bugbee
# 2397         None         None       By Teo Bugbee
# 2398         None         None       By Teo Bugbee
# 2399         None         None       By Teo Bugbee
#
#                                           byline.person byline.organization
# 0     [{'firstname': 'Beatrice', 'middlename': None,...                None
# 1     [{'firstname': 'Beatrice', 'middlename': None,...                None
# 2     [{'firstname': 'Beatrice', 'middlename': None,...                None
# 3     [{'firstname': 'Beatrice', 'middlename': None,...                None
# 4     [{'firstname': 'Beatrice', 'middlename': None,...                None
# ...                                                 ...                 ...
# 2395  [{'firstname': 'Teo', 'middlename': None, 'las...                None
# 2396  [{'firstname': 'Teo', 'middlename': None, 'las...                None
# 2397  [{'firstname': 'Teo', 'middlename': None, 'las...                None
# 2398  [{'firstname': 'Teo', 'middlename': None, 'las...                None
# 2399  [{'firstname': 'Teo', 'middlename': None, 'las...                None
#
# [2400 rows x 31 columns]

# %%
# Drop "byline.person" column
combined_title_df.drop("byline.person",axis=1, inplace=True)
combined_title_df
# Out:
#              title original_title  budget original_language  \
# 0       After Love     After Love       0                en
# 1       After Love     After Love       0                en
# 2       After Love     After Love       0                en
# 3       After Love     After Love       0                en
# 4       After Love     After Love       0                en
# ...            ...            ...     ...               ...
# 2395  My Policeman   My Policeman       0                en
# 2396  My Policeman   My Policeman       0                en
# 2397  My Policeman   My Policeman       0                en
# 2398  My Policeman   My Policeman       0                en
# 2399  My Policeman   My Policeman       0                en
#
#                                   homepage  \
# 0
# 1
# 2
# 3
# 4
# ...                                    ...
# 2395  https://www.amazon.com/dp/B09Y8SHDPD
# 2396  https://www.amazon.com/dp/B09Y8SHDPD
# 2397  https://www.amazon.com/dp/B09Y8SHDPD
# 2398  https://www.amazon.com/dp/B09Y8SHDPD
# 2399  https://www.amazon.com/dp/B09Y8SHDPD
#
#                                                overview  popularity  runtime  \
# 0     Set in the port town of Dover in the South-Eas...      20.945       89
# 1     Set in the port town of Dover in the South-Eas...      20.945       89
# 2     Set in the port town of Dover in the South-Eas...      20.945       89
# 3     Set in the port town of Dover in the South-Eas...      20.945       89
# 4     Set in the port town of Dover in the South-Eas...      20.945       89
# ...                                                 ...         ...      ...
# 2395  In the late 1990s, the arrival of elderly inva...      24.341      113
# 2396  In the late 1990s, the arrival of elderly inva...      24.341      113
# 2397  In the late 1990s, the arrival of elderly inva...      24.341      113
# 2398  In the late 1990s, the arrival of elderly inva...      24.341      113
# 2399  In the late 1990s, the arrival of elderly inva...      24.341      113
#
#       revenue release_date  ...  word_count  \
# 0           0   2021-06-04  ...         359
# 1           0   2021-06-04  ...         359
# 2           0   2021-06-04  ...         359
# 3           0   2021-06-04  ...         359
# 4           0   2021-06-04  ...         359
# ...       ...          ...  ...         ...
# 2395        0   2022-10-20  ...         303
# 2396        0   2022-10-20  ...         303
# 2397        0   2022-10-20  ...         303
# 2398        0   2022-10-20  ...         303
# 2399        0   2022-10-20  ...         303
#
#                                           headline.main headline.kicker  \
# 0                  ‘After Love’ Review: The Other Woman   Critic’s Pick
# 1                  ‘After Love’ Review: The Other Woman   Critic’s Pick
# 2                  ‘After Love’ Review: The Other Woman   Critic’s Pick
# 3                  ‘After Love’ Review: The Other Woman   Critic’s Pick
# 4                  ‘After Love’ Review: The Other Woman   Critic’s Pick
# ...                                                 ...             ...
# 2395  ‘My Policeman’ Review: Two Love Affairs, Equal...            None
# 2396  ‘My Policeman’ Review: Two Love Affairs, Equal...            None
# 2397  ‘My Policeman’ Review: Two Love Affairs, Equal...            None
# 2398  ‘My Policeman’ Review: Two Love Affairs, Equal...            None
# 2399  ‘My Policeman’ Review: Two Love Affairs, Equal...            None
#
#      headline.content_kicker headline.print_headline headline.name  \
# 0                       None              After Love          None
# 1                       None              After Love          None
# 2                       None              After Love          None
# 3                       None              After Love          None
# 4                       None              After Love          None
# ...                      ...                     ...           ...
# 2395                    None            My Policeman          None
# 2396                    None            My Policeman          None
# 2397                    None            My Policeman          None
# 2398                    None            My Policeman          None
# 2399                    None            My Policeman          None
#
#      headline.seo headline.sub     byline.original byline.organization
# 0            None         None  By Beatrice Loayza                None
# 1            None         None  By Beatrice Loayza                None
# 2            None         None  By Beatrice Loayza                None
# 3            None         None  By Beatrice Loayza                None
# 4            None         None  By Beatrice Loayza                None
# ...           ...          ...                 ...                 ...
# 2395         None         None       By Teo Bugbee                None
# 2396         None         None       By Teo Bugbee                None
# 2397         None         None       By Teo Bugbee                None
# 2398         None         None       By Teo Bugbee                None
# 2399         None         None       By Teo Bugbee                None
#
# [2400 rows x 30 columns]

# %%
# Delete duplicate rows and reset index
combined_title_df.drop_duplicates(inplace=True)
combined_title_df.reset_index(drop=True, inplace=True)
combined_title_df
# Out:
#                     title          original_title    budget original_language  \
# 0              After Love              After Love         0                en
# 1                Alcarràs                Alcarràs         0                ca
# 2  The Sound of Christmas  The Sound of Christmas         0                en
# 3          The Inspection          The Inspection         0                en
# 4           Bones and All           Bones and All  16000000                it
# 5            My Policeman            My Policeman         0                en
#
#                                 homepage  \
# 0
# 1         https://www.alcarras-film.com/
# 2
# 3  https://a24films.com/films/inspection
# 4       https://www.bonesandallfilm.net/
# 5   https://www.amazon.com/dp/B09Y8SHDPD
#
#                                             overview  popularity  runtime  \
# 0  Set in the port town of Dover in the South-Eas...      20.945       89
# 1  In a small village in Catalonia, the peach far...      14.598      120
# 2  A woman facing eviction just before Christmas ...       1.173        0
# 3  Ellis French is a young, gay Black man, reject...      26.393       95
# 4  Abandoned by her father, a young woman embarks...      30.307      131
# 5  In the late 1990s, the arrival of elderly inva...      24.341      113
#
#     revenue release_date  ...  word_count  \
# 0         0   2021-06-04  ...         359
# 1         0   2022-04-29  ...         306
# 2         0   2022-11-24  ...         277
# 3    270613   2022-11-18  ...         836
# 4  15234907   2022-11-18  ...         710
# 5         0   2022-10-20  ...         303
#
#                                        headline.main headline.kicker  \
# 0               ‘After Love’ Review: The Other Woman   Critic’s Pick
# 1                   ‘Alcarràs’ Review: Labor of Love            None
# 2  ‘The Sound of Christmas’ Review: A Gospel Sing...            None
# 3   ‘The Inspection’ Review: Boot Camp, a Love Story   critic’s pick
# 4       ‘Bones and All’ Review: You Eat What You Are            None
# 5  ‘My Policeman’ Review: Two Love Affairs, Equal...            None
#
#   headline.content_kicker                            headline.print_headline  \
# 0                    None                                         After Love
# 1                    None                                           Alcarràs
# 2                    None                            The Sound  Of Christmas
# 3                    None                  A Few Good Men, Some With Secrets
# 4                    None  It’s Eat, Prey, Love on a Journey of Self-Disc...
# 5                    None                                       My Policeman
#
#   headline.name headline.seo headline.sub        byline.original  \
# 0          None         None         None     By Beatrice Loayza
# 1          None         None         None       By Devika Girish
# 2          None         None         None  By Concepción de León
# 3          None         None         None          By A.O. Scott
# 4          None         None         None          By A.O. Scott
# 5          None         None         None          By Teo Bugbee
#
#   byline.organization
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
# 5                None
#
# [6 rows x 30 columns]

# %%
# Export data to CSV without the index
combined_title_df.to_csv("collected_data_actual.csv", index=False)
